# %% [markdown]
# ANN
# Mathematical Requirements
# 1. Functions
# 2. Vectors
# 3. Linear Algebra (Matrix Multiplication, Transpose Matrix)
# 4. Differential Calculas (Gradiant, Partial Derivatives)
# 5. Graphs
#
# Programming Requirements
# 1. Python
# 2. OOP
# 3. IDE

# %% [markdown]
# Perceptron
