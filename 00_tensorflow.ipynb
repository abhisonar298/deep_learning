# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.9.1'

# %%
scaler = tf.constant(7)
scaler
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=7>

# %%
scaler.ndim
# Out:
# 0

# %%
vector = tf.constant([10, 7])
vector
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([10,  7])>

# %%
vector.ndim
# Out:
# 1

# %%
matrix = tf.constant([
    [1,2],
    [3,4]
])
matrix
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]])>

# %%
matrix.ndim
# Out:
# 2

# %%
matrix = tf.constant([
    [1.,2.],
    [3.,4.],
    [5.,6.]
],
dtype=tf.float16)
matrix
# Out:
# <tf.Tensor: shape=(3, 2), dtype=float16, numpy=
# array([[1., 2.],
#        [3., 4.],
#        [5., 6.]], dtype=float16)>

# %%
matrix = tf.constant(
    [[[1.,2.],
    [3.,4.],
    [5.,6.]],

    [[1.,2.],
    [3.,4.],
    [5.,6.]],

    [[1.,2.],
    [3.,4.],
    [5.,6.]]],
dtype=tf.float16)
matrix
# Out:
# <tf.Tensor: shape=(3, 3, 2), dtype=float16, numpy=
# array([[[1., 2.],
#         [3., 4.],
#         [5., 6.]],
#
#        [[1., 2.],
#         [3., 4.],
#         [5., 6.]],
#
#        [[1., 2.],
#         [3., 4.],
#         [5., 6.]]], dtype=float16)>

# %%
matrix.ndim
# Out:
# 3

# %%
v = tf.Variable(
    [10,7]
)
c = tf.constant(
    [10,7]
)
v, c
# Out:
# (<tf.Variable 'Variable:0' shape=(2,) dtype=int32, numpy=array([10,  7])>,
#  <tf.Tensor: shape=(2,), dtype=int32, numpy=array([10,  7])>)

# %%
v[0].assign(7)
# Out:
# <tf.Variable 'UnreadVariable' shape=(2,) dtype=int32, numpy=array([7, 7])>

# %%
v
# Out:
# <tf.Variable 'Variable:0' shape=(2,) dtype=int32, numpy=array([7, 7])>

# %% [markdown]
# tf.variable is mutable
#
# tf.constant is immutable

# %% [markdown]
# ## Random Tensor

# %%
tf.random.uniform(shape=(2,2))
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[0.8088157 , 0.508307  ],
#        [0.6434394 , 0.19937313]], dtype=float32)>

# %%
tf.random.normal(shape=(2,2))
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[0.26686352, 0.92856604],
#        [0.19417116, 0.58083004]], dtype=float32)>

# %% [markdown]
# ### Shuffling

# %%
a = tf.constant(
    [[1,2],
    [3,4],
    [4,5],
    [6,7],
    [8,9]]
)

# %%
tf.random.set_seed(1)  # global level seed
tf.random.shuffle(a, seed=10)  # operation level seed

# when both seeds are same shuffling will be the output
# Out:
# <tf.Tensor: shape=(5, 2), dtype=int32, numpy=
# array([[6, 7],
#        [8, 9],
#        [1, 2],
#        [4, 5],
#        [3, 4]])>

# %%
tf.random.set_seed(10)
tf.random.shuffle(a, seed=10)
# Out:
# <tf.Tensor: shape=(5, 2), dtype=int32, numpy=
# array([[6, 7],
#        [4, 5],
#        [1, 2],
#        [8, 9],
#        [3, 4]])>

# %%
tf.constant()
